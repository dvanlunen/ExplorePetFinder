# %% [markdown]
# # PetFinder API Tests
#
# Using the PetFinder API, get data about pets for analysis. Data comes in a messy JSON.

# %% [markdown]
# ### Imports

# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize
from IPython.display import Image, display
from IPython.core.display import HTML
import re
import os.path

# %% [markdown]
# ### Constants

# %%
with open('./hidden/PETFINDER_API_KEY.txt') as f:
    KEY = f.read().replace('\n', '')

# %% [markdown]
# ### Test API Call: Getting a random pet

# %%
parameters = {"key": KEY,
              "format": "json",
              "output": "full",
              "location": "02472",
              "animal": "dog"}
response = requests.get('http://api.petfinder.com/pet.getRandom',
                        params=parameters)

# %%
print(response.content)
# Out:
# {"@encoding":"iso-8859-1","@version":"1.0","petfinder":{"pet":{"options":{},"status":{"$t":"A"},"contact":{"phone":{"$t":"706-541-4077  "},"state":{"$t":"GA"},"address2":{},"email":{"$t":"rfranks@columbiacountyga.gov"},"city":{"$t":"Appling"},"zip":{"$t":"30802"},"fax":{},"address1":{"$t":"1940 William Few Parkway"}},"age":{"$t":"Adult"},"size":{"$t":"M"},"media":{"photos":{"photo":[{"@size":"pnt","$t":"http://photos.petfinder.com/photos/pets/41163550/1/?bust=1520908063&width=60&-pnt.jpg","@id":"1"},{"@size":"fpm","$t":"http://photos.petfinder.com/photos/pets/41163550/1/?bust=1520908063&width=95&-fpm.jpg","@id":"1"},{"@size":"x","$t":"http://photos.petfinder.com/photos/pets/41163550/1/?bust=1520908063&width=500&-x.jpg","@id":"1"},{"@size":"pn","$t":"http://photos.petfinder.com/photos/pets/41163550/1/?bust=1520908063&width=300&-pn.jpg","@id":"1"},{"@size":"t","$t":"http://photos.petfinder.com/photos/pets/41163550/1/?bust=1520908063&width=50&-t.jpg","@id":"1"}]}},"id":{"$t":"41163550"},"shelterPetId":{"$t":"A083843"},"breeds":{"breed":[{"$t":"Shiba Inu"},{"$t":"Mixed Breed"}]},"name":{"$t":"A083843"},"sex":{"$t":"F"},"description":{"$t":"This animal was rescued by:       A Citizen    Date animal was rescued: 03/06/18  Date animal was brought to the shelter: 03/06/18  Location where animal was found:  Old Louisville Rd, Grovetown  If you believe this is your lost pet, please contact Columbia County Animal Services at (706) 541-4077 and make note of the animals ID number (A________).  You are also encouraged to visit the shelter Monday through Friday from 10:30 a.m. to 4:30 p.m. to view animals  to aid in locating your lost pet."},"mix":{"$t":"yes"},"shelterId":{"$t":"GA257"},"lastUpdate":{"$t":"2018-03-13T01:04:20Z"},"animal":{"$t":"Dog"}},"@xmlns:xsi":"http://www.w3.org/2001/XMLSchema-instance","header":{"timestamp":{"$t":"2018-03-13T03:57:27Z"},"status":{"message":{},"code":{"$t":"100"}},"version":{"$t":"0.1"}},"@xsi:noNamespaceSchemaLocation":"http://api.petfinder.com/schemas/0.9/petfinder.xsd"}}

# %% [markdown]
# json is quite a mess, let's take a peek

# %%
data = json.loads(response.content)
print(json.dumps(data["petfinder"]["pet"], indent=4, sort_keys=True))
# Out:
# {
#     "age": {
#         "$t": "Adult"
#     },
#     "animal": {
#         "$t": "Dog"
#     },
#     "breeds": {
#         "breed": [
#             {
#                 "$t": "Shiba Inu"
#             },
#             {
#                 "$t": "Mixed Breed"
#             }
#         ]
#     },
#     "contact": {
#         "address1": {
#             "$t": "1940 William Few Parkway"
#         },
#         "address2": {},
#         "city": {
#             "$t": "Appling"
#         },
#         "email": {
#             "$t": "rfranks@columbiacountyga.gov"
#         },
#         "fax": {},
#         "phone": {
#             "$t": "706-541-4077  "
#         },
#         "state": {
#             "$t": "GA"
#         },
#         "zip": {
#             "$t": "30802"
#         }
#     },
#     "description": {
#         "$t": "This animal was rescued by:       A Citizen    Date animal was rescued: 03/06/18  Date animal was brought to the shelter: 03/06/18  Location where animal was found:  Old Louisville Rd, Grovetown  If you believe this is your lost pet, please contact Columbia County Animal Services at (706) 541-4077 and make note of the animals ID number (A________).  You are also encouraged to visit the shelter Monday through Friday from 10:30 a.m. to 4:30 p.m. to view animals  to aid in locating your lost pet."
#     },
#     "id": {
#         "$t": "41163550"
#     },
#     "lastUpdate": {
#         "$t": "2018-03-13T01:04:20Z"
#     },
#     "media": {
#         "photos": {
#             "photo": [
#                 {
#                     "$t": "http://photos.petfinder.com/photos/pets/41163550/1/?bust=1520908063&width=60&-pnt.jpg",
#                     "@id": "1",
#                     "@size": "pnt"
#                 },
#                 {
#                     "$t": "http://photos.petfinder.com/photos/pets/41163550/1/?bust=1520908063&width=95&-fpm.jpg",
#                     "@id": "1",
#                     "@size": "fpm"
#                 },
#                 {
#                     "$t": "http://photos.petfinder.com/photos/pets/41163550/1/?bust=1520908063&width=500&-x.jpg",
#                     "@id": "1",
#                     "@size": "x"
#                 },
#                 {
#                     "$t": "http://photos.petfinder.com/photos/pets/41163550/1/?bust=1520908063&width=300&-pn.jpg",
#                     "@id": "1",
#                     "@size": "pn"
#                 },
#                 {
#                     "$t": "http://photos.petfinder.com/photos/pets/41163550/1/?bust=1520908063&width=50&-t.jpg",
#                     "@id": "1",
#                     "@size": "t"
#                 }
#             ]
#         }
#     },
#     "mix": {
#         "$t": "yes"
#     },
#     "name": {
#         "$t": "A083843"
#     },
#     "options": {},
#     "sex": {
#         "$t": "F"
#     },
#     "shelterId": {
#         "$t": "GA257"
#     },
#     "shelterPetId": {
#         "$t": "A083843"
#     },
#     "size": {
#         "$t": "M"
#     },
#     "status": {
#         "$t": "A"
#     }
# }

# %%
json_normalize(data["petfinder"]["pet"])
# Out:
#   age.$t animal.$t                                      breeds.breed  \
# 0  Adult       Dog  [{u'$t': u'Shiba Inu'}, {u'$t': u'Mixed Breed'}]
#
#         contact.address1.$t contact.city.$t              contact.email.$t  \
# 0  1940 William Few Parkway         Appling  rfranks@columbiacountyga.gov
#
#   contact.phone.$t contact.state.$t contact.zip.$t  \
# 0   706-541-4077                 GA          30802
#
#                                       description.$t     id.$t  \
# 0  This animal was rescued by:       A Citizen   ...  41163550
#
#           lastUpdate.$t                                 media.photos.photo  \
# 0  2018-03-13T01:04:20Z  [{u'$t': u'http://photos.petfinder.com/photos/...
#
#   mix.$t  name.$t sex.$t shelterId.$t shelterPetId.$t size.$t status.$t
# 0    yes  A083843      F        GA257         A083843       M         A

# %% [markdown]
# Embedded arrays could use some flattening

# %%
def flatten_json(y):
    """ recursively loop through JSON
    flattening embedded arrays and dicts
    output flattened version that is easy normalize
    -thanks Amir Ziai
    """
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out


flat = flatten_json(data["petfinder"]["pet"])
pet_data = json_normalize(flat)
print(pet_data.columns)
pet_data.transpose()
# Out:
# Index([u'age_$t', u'animal_$t', u'breeds_breed_0_$t', u'breeds_breed_1_$t',
#        u'contact_address1_$t', u'contact_city_$t', u'contact_email_$t',
#        u'contact_phone_$t', u'contact_state_$t', u'contact_zip_$t',
#        u'description_$t', u'id_$t', u'lastUpdate_$t',
#        u'media_photos_photo_0_$t', u'media_photos_photo_0_@id',
#        u'media_photos_photo_0_@size', u'media_photos_photo_1_$t',
#        u'media_photos_photo_1_@id', u'media_photos_photo_1_@size',
#        u'media_photos_photo_2_$t', u'media_photos_photo_2_@id',
#        u'media_photos_photo_2_@size', u'media_photos_photo_3_$t',
#        u'media_photos_photo_3_@id', u'media_photos_photo_3_@size',
#        u'media_photos_photo_4_$t', u'media_photos_photo_4_@id',
#        u'media_photos_photo_4_@size', u'mix_$t', u'name_$t', u'sex_$t',
#        u'shelterId_$t', u'shelterPetId_$t', u'size_$t', u'status_$t'],
#       dtype='object')
#                                                                             0
# age_$t                                                                  Adult
# animal_$t                                                                 Dog
# breeds_breed_0_$t                                                   Shiba Inu
# breeds_breed_1_$t                                                 Mixed Breed
# contact_address1_$t                                  1940 William Few Parkway
# contact_city_$t                                                       Appling
# contact_email_$t                                 rfranks@columbiacountyga.gov
# contact_phone_$t                                               706-541-4077
# contact_state_$t                                                           GA
# contact_zip_$t                                                          30802
# description_$t              This animal was rescued by:       A Citizen   ...
# id_$t                                                                41163550
# lastUpdate_$t                                            2018-03-13T01:04:20Z
# media_photos_photo_0_$t     http://photos.petfinder.com/photos/pets/411635...
# media_photos_photo_0_@id                                                    1
# media_photos_photo_0_@size                                                pnt
# media_photos_photo_1_$t     http://photos.petfinder.com/photos/pets/411635...
# media_photos_photo_1_@id                                                    1
# media_photos_photo_1_@size                                                fpm
# media_photos_photo_2_$t     http://photos.petfinder.com/photos/pets/411635...
# media_photos_photo_2_@id                                                    1
# media_photos_photo_2_@size                                                  x
# media_photos_photo_3_$t     http://photos.petfinder.com/photos/pets/411635...
# media_photos_photo_3_@id                                                    1
# media_photos_photo_3_@size                                                 pn
# media_photos_photo_4_$t     http://photos.petfinder.com/photos/pets/411635...
# media_photos_photo_4_@id                                                    1
# media_photos_photo_4_@size                                                  t
# mix_$t                                                                    yes
# name_$t                                                               A083843
# sex_$t                                                                      F
# shelterId_$t                                                            GA257
# shelterPetId_$t                                                       A083843
# size_$t                                                                     M
# status_$t                                                                   A

# %% [markdown]
# What kind of beautiful beast are we looking at?

# %%
# loop through the photo columns displaying them
for col in pet_data.columns:
    if re.match('media_photos_photo_[0-9]+_\$t', col):
        display(Image(url=pet_data.loc[0, col]))
# Out:
# <img src="http://photos.petfinder.com/photos/pets/41163550/1/?bust=1520908063&width=60&-pnt.jpg"/>
# <img src="http://photos.petfinder.com/photos/pets/41163550/1/?bust=1520908063&width=95&-fpm.jpg"/>
# <img src="http://photos.petfinder.com/photos/pets/41163550/1/?bust=1520908063&width=500&-x.jpg"/>
# <img src="http://photos.petfinder.com/photos/pets/41163550/1/?bust=1520908063&width=300&-pn.jpg"/>
# <img src="http://photos.petfinder.com/photos/pets/41163550/1/?bust=1520908063&width=50&-t.jpg"/>

# %% [markdown]
# ### Pull More Data at Once

# %%
parameters = {"key": KEY,
              "animal": "dog",
              "count": 1000,
              "output": "full",
              "format": "json",
              "location": "02472"
              }

response = requests.get('http://api.petfinder.com/pet.find',
                         params=parameters)

# %%
data = json.loads(response.content)
# print(json.dumps(data, indent=4, sort_keys=True))

# %%
flat = flatten_json(data["petfinder"]["pets"]["pet"])
df = pd.DataFrame([flatten_json(x) for x in data["petfinder"]["pets"]["pet"]])
df.head()
# Out:
#    age_$t animal_$t breeds_breed_$t  breeds_breed_0_$t   breeds_breed_1_$t  \
# 0   Young       Dog             NaN          Chihuahua             Terrier
# 1   Young       Dog       Chihuahua                NaN                 NaN
# 2   Young       Dog       Retriever                NaN                 NaN
# 3  Senior       Dog             NaN  Australian Kelpie  Labrador Retriever
# 4   Young       Dog             NaN      Border Collie          Cattle Dog
#
#   contact_address1_$t contact_address2_$t contact_city_$t  \
# 0                 NaN                 NaN          Newton
# 1                 NaN                 NaN          Newton
# 2                 NaN                 NaN          Newton
# 3                 NaN                 NaN          Newton
# 4                 NaN                 NaN          Newton
#
#              contact_email_$t contact_phone_$t    ...    options_option_2_$t  \
# 0  rhondabarron@earthlink.net       7133045266    ...                    NaN
# 1  rhondabarron@earthlink.net       7133045266    ...                    NaN
# 2  rhondabarron@earthlink.net       7133045266    ...                    NaN
# 3  rhondabarron@earthlink.net       7133045266    ...                 noCats
# 4  rhondabarron@earthlink.net       7133045266    ...                    NaN
#
#   options_option_3_$t options_option_4_$t options_option_5_$t  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#   options_option_6_$t sex_$t shelterId_$t shelterPetId_$t size_$t status_$t
# 0                 NaN      F       TX1961             NaN       S         A
# 1                 NaN      M       TX1961             NaN       S         A
# 2                 NaN      M       TX1961             NaN       M         A
# 3                 NaN      F       TX1961             NaN       M         A
# 4                 NaN      M       TX1961             NaN       M         A
#
# [5 rows x 120 columns]

# %% [markdown]
# #### Write the data to output

# %%
f = './hidden/dog_data.csv'
if os.path.isfile(f):
    df.to_csv(f, mode='a', header=False, encoding='utf-8')
else:
    df.to_csv(f, encoding='utf-8')
