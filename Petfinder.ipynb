# %%
import requests
import json
import pandas as pd

# %%
key = '2a7c7f0af3acad37d866076f719250f2'

# %%
parameters = {"key": key,
             "format": "json",
             "output": "full",
             "location": "02472",
             "animal": "dog"}
response = requests.get('http://api.petfinder.com/pet.getRandom',
                       params=parameters)
print(response.status_code)
# Out:
# 200

# %%
print(response.content)
# Out:
# {"@encoding":"iso-8859-1","@version":"1.0","petfinder":{"pet":{"options":{"option":{"$t":"hasShots"}},"status":{"$t":"A"},"contact":{"phone":{"$t":"(240) 350-9192"},"state":{"$t":"MD"},"address2":{},"email":{"$t":"sdk9rehab@gmail.com"},"city":{"$t":"Hughesville"},"zip":{"$t":"20637"},"fax":{},"address1":{}},"age":{"$t":"Baby"},"size":{"$t":"M"},"media":{"photos":{"photo":[{"@size":"pnt","$t":"http://photos.petfinder.com/photos/pets/40906791/1/?bust=1518184558&width=60&-pnt.jpg","@id":"1"},{"@size":"fpm","$t":"http://photos.petfinder.com/photos/pets/40906791/1/?bust=1518184558&width=95&-fpm.jpg","@id":"1"},{"@size":"x","$t":"http://photos.petfinder.com/photos/pets/40906791/1/?bust=1518184558&width=500&-x.jpg","@id":"1"},{"@size":"pn","$t":"http://photos.petfinder.com/photos/pets/40906791/1/?bust=1518184558&width=300&-pn.jpg","@id":"1"},{"@size":"t","$t":"http://photos.petfinder.com/photos/pets/40906791/1/?bust=1518184558&width=50&-t.jpg","@id":"1"}]}},"id":{"$t":"40906791"},"shelterPe
# ...

# %%
data = json.loads(response.content)
print type(data)
# Out:
# <type 'dict'>
#                                  @encoding  @version  \
# @xmlns:xsi                      iso-8859-1         1
# @xsi:noNamespaceSchemaLocation  iso-8859-1         1
# header                          iso-8859-1         1
# pet                             iso-8859-1         1
#
#                                                                         petfinder
# @xmlns:xsi                              http://www.w3.org/2001/XMLSchema-instance
# @xsi:noNamespaceSchemaLocation  http://api.petfinder.com/schemas/0.9/petfinder...
# header                          {u'status': {u'message': {}, u'code': {u'$t': ...
# pet                             {u'status': {u'$t': u'A'}, u'shelterId': {u'$t...

# %%
print(json.dumps(data["petfinder"]["pet"], indent=4, sort_keys=True))
# Out:
# {
#     "age": {
#         "$t": "Baby"
#     },
#     "animal": {
#         "$t": "Dog"
#     },
#     "breeds": {
#         "breed": {
#             "$t": "Boxer"
#         }
#     },
#     "contact": {
#         "address1": {},
#         "address2": {},
#         "city": {
#             "$t": "Hughesville"
#         },
#         "email": {
#             "$t": "sdk9rehab@gmail.com"
#         },
#         "fax": {},
#         "phone": {
#             "$t": "(240) 350-9192"
#         },
#         "state": {
#             "$t": "MD"
#         },
#         "zip": {
#             "$t": "20637"
#         }
#     },
#     "description": {
# ...

# %%
test = pd.read_json(json.dumps(data["petfinder"]["pet"]))
print test.head()
# Out:
#            age animal             breeds                  contact  \
# $t        Baby    Dog                NaN                      NaN
# address1   NaN    NaN                NaN                       {}
# address2   NaN    NaN                NaN                       {}
# breed      NaN    NaN  {u'$t': u'Boxer'}                      NaN
# city       NaN    NaN                NaN  {u'$t': u'Hughesville'}
#
#                                                 description          id  \
# $t        Meet Snickers, one of 9 beautiful puppies that...  40906791.0
# address1                                                NaN         NaN
# address2                                                NaN         NaN
# breed                                                   NaN         NaN
# city                                                    NaN         NaN
#
#                     lastUpdate media  mix      name options  sex shelterId  \
# ...

# %%
parameters = {"key": key,
              "animal": "dog",
              "count": 1000,
              "output": "full",
              "format": "json",
              "location": "02472"
             }

response2 = requests.get('http://api.petfinder.com/pet.find',
                         params=parameters)

# %%
print response2.status_code
data2 = json.loads(response2.content)
print json.dumps(data2, indent=4, sort_keys=True)
# Out:
# 200
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print('http://api.petfinder.com/pet.find?key=' + key +
      '&animal=dog&count=25&output=full&format=json')
# Out:
# http://api.petfinder.com/pet.find?key=2a7c7f0af3acad37d866076f719250f2&animal=dog&count=25&output=full&format=json

# %%
parameters = {"key": key,
              "animal": "dog",
              "count": 10,
              "output": "full",
              "format": "json",
              "location": "02472"
             }

response3 = requests.get('http://api.petfinder.com/pet.find',
                         params=parameters)

# %%
print response3.status_code
data3 = json.loads(response3.content)
print json.dumps(data3, indent=4, sort_keys=True)
# Out:
# 200
# {
#     "@encoding": "iso-8859-1",
#     "@version": "1.0",
#     "petfinder": {
#         "@xmlns:xsi": "http://www.w3.org/2001/XMLSchema-instance",
#         "@xsi:noNamespaceSchemaLocation": "http://api.petfinder.com/schemas/0.9/petfinder.xsd",
#         "header": {
#             "status": {
#                 "code": {
#                     "$t": "100"
#                 },
#                 "message": {}
#             },
#             "timestamp": {
#                 "$t": "2018-02-14T03:23:14Z"
#             },
#             "version": {
#                 "$t": "0.1"
#             }
#         },
#         "lastOffset": {
#             "$t": "10"
#         },
#         "pets": {
#             "pet": [
#                 {
#                     "age": {
#                         "$t": "Adult"
#                     },
#                     "animal": {
#                         "$t": "Dog"
#                     },
#                     "breeds": {
# ...
